# %%
import pandas as pd
from SCPIntModel import *

# %%
import scanpy as sc

# %%
multibatch_ann = sc.read_h5ad('../data/task_data/multi_batch_task_four_sets_ann.h5ad')

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 1937 × 554
#     obs: 'celltype', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
processor = AnnDataProcessor(multibatch_ann, batch_key="batch")
# Out:
# Loaded 1937 cells × 554 proteins
# Batches (4): ['derks', 'leduc2021', 'leduc2023', 'specht']

# %%
model_name = "multibatch_cls-0.1_adv-0.3_mse-1_warmup-1_lr-0.01_epoch-1000.pt"

# %%
trainer = Trainer.load(f"../data/model/saved/{model_name}")
# Out:
# Model loaded from ../data/model/saved/multibatch_cls-0.1_adv-0.3_mse-1_warmup-1_lr-0.01_epoch-1000.pt

# %%
X_tensor, _ = processor.to_tensors()

# %%
bio_emb, batch_emb = trainer.encode(X_tensor)

# %%
multibatch_ann.obsm["X_SCPInt"] = bio_emb.numpy()

# %%
multibatch_ann.obsm['batch_em'] = batch_emb.numpy()

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 1937 × 554
#     obs: 'celltype', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_SCPInt', 'batch_em'
#     varm: 'PCs'

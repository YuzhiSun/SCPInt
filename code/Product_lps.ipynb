# %%
import pandas as pd
from SCPIntModel import *

# %%
import scanpy as sc

# %%
multibatch_ann = sc.read_h5ad('../data/task_data/lps_ann.h5ad')

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 1863 × 714
#     obs: 'celltype', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'

# %%
processor = AnnDataProcessor(multibatch_ann, batch_key="batch")
# Out:
# Loaded 1863 cells × 714 proteins
# Batches (2): ['huffman', 'specht']

# %%
model_name = "lps_cls-0.4_adv-0.1_mse-0.5_warmup-1_lr-0.01_epoch-1000.pt"

# %%
trainer = Trainer.load(f"../data/model/saved/{model_name}")
# Out:
# Model loaded from ../data/model/saved/lps_cls-0.4_adv-0.1_mse-0.5_warmup-1_lr-0.01_epoch-1000.pt

# %%
X_tensor, _ = processor.to_tensors()

# %%
bio_emb, batch_emb = trainer.encode(X_tensor)

# %%
multibatch_ann.obsm["X_SCPInt"] = bio_emb.numpy()

# %%
multibatch_ann.obsm['batch_em'] = batch_emb.numpy()

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 1863 × 714
#     obs: 'celltype', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_SCPInt', 'batch_em'
#     varm: 'PCs'

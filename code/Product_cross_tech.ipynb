# %%
import pandas as pd
from SCPIntModel import *

# %%
import scanpy as sc

# %%
multibatch_ann = sc.read_h5ad('../data/task_data/cross_tech_ann.h5ad')

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 297 × 920
#     obs: 'Raw.file', 'celltype', 'cvm', 'RI', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
processor = AnnDataProcessor(multibatch_ann, batch_key="batch")
# Out:
# Loaded 297 cells × 920 proteins
# Batches (3): ['pSCoPE1', 'pSCoPE2', 'shotgun']

# %%
model_name = "cross_tech_cls-0.1_adv-0.3_mse-0.5_warmup-1_lr-0.01_epoch-1000.pt"

# %%
trainer = Trainer.load(f"../data/model/saved/{model_name}")
# Out:
# Model loaded from ../data/model/saved/cross_tech_cls-0.1_adv-0.3_mse-0.5_warmup-1_lr-0.01_epoch-1000.pt

# %%
X_tensor, _ = processor.to_tensors()

# %%
bio_emb, batch_emb = trainer.encode(X_tensor)

# %%
multibatch_ann.obsm["X_SCPInt"] = bio_emb.numpy()

# %%
multibatch_ann.obsm['batch_em'] = batch_emb.numpy()

# %%
multibatch_ann
# Out:
# AnnData object with n_obs × n_vars = 297 × 920
#     obs: 'Raw.file', 'celltype', 'cvm', 'RI', 'batch'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_SCPInt', 'batch_em'
#     varm: 'PCs'
